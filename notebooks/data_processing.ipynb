# %%
import pandas as pd
import sklearn

# %%
sklearn.__version__
# Out:
# '1.5.0'

# %%
from pathlib import Path
df = pd.read_csv(Path("../data/raw/flats.csv"))

# %%
df.head()
# Out:
#                      property_name  \
# 0     2 BHK Flat in Krishna Colony
# 1        2 BHK Flat in Ashok Vihar
# 2              2 BHK Flat in Sohna
# 3  2 BHK Flat in Sector 61 Gurgaon
# 4  2 BHK Flat in Sector 92 Gurgaon
#
#                                                 link                 society  \
# 0  https://www.99acres.com/2-bhk-bedroom-apartmen...  maa bhagwati residency
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...            Apna Enclave
# 2  https://www.99acres.com/2-bhk-bedroom-apartmen...  Tulsiani Easy in Homes
# 3  https://www.99acres.com/2-bhk-bedroom-apartmen...     Smart World Orchard
# 4  https://www.99acres.com/2-bhk-bedroom-apartmen...        Parkwood Westend
#
#         price             area                            areaWithType  \
# 0      45 Lac   ₹ 5,000/sq.ft.          Carpet area: 900 (83.61 sq.m.)
# 1      50 Lac   ₹ 7,692/sq.ft.          Carpet area: 650 (60.39 sq.m.)
# 2      40 Lac   ₹ 6,722/sq.ft.          Carpet area: 595 (55.28 sq.m.)
# 3  1.47 Crore  ₹ 12,250/sq.ft.        Carpet area: 1200 (111.48 sq.m.)
# 4      70 Lac   ₹ 5,204/sq.ft.  Super Built up area 1345(124.95 sq.m.)
#
#       bedRoom     bathroom      balcony additionalRoom  \
# 0  2 Bedrooms  2 Bathrooms    1 Balcony            NaN
# 1  2 Bedrooms  2 Bathrooms    1 Balcony            NaN
# 2  2 Bedrooms  2 Bathrooms  3 Balconies            NaN
# 3  2 Bedrooms  2 Bathrooms  2 Balconies     Study Room
# 4  2 Bedrooms  2 Bathrooms  3 Balconies     Study Room
#
#                                address             floorNum facing  \
# 0     Krishna Colony, Gurgaon, Haryana    4th   of 4 Floors   West
# 1   46b, Ashok Vihar, Gurgaon, Haryana    1st   of 3 Floors   West
# 2              Sohna, Gurgaon, Haryana  12nd   of 14 Floors    NaN
# 3  Sector 61 Gurgaon, Gurgaon, Haryana    2nd   of 4 Floors    NaN
# 4  Sector 92 Gurgaon, Gurgaon, Haryana    5th   of 8 Floors    NaN
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1        10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2     0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 3            Dec 2023  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4  Under Construction  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating property_id
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...   C68850746
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...   H68850564
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...   J68850120
# 3                                                NaN   S68849476
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...   L47956793

# %%
df.shape
# Out:
# (3028, 20)

# %%
# to drop link col no need 
df.drop(columns=['link','property_id'],inplace=True)

# %%
# Now let's clean each column one by one
# rename columns
df.rename(columns={'area':'price_per_sqft'},inplace=True)

# %%
df['society'].value_counts()
# Out:
# society
# SS The Leaf3.8 ★                             73
# Tulip Violet4.3 ★                            40
# Shapoorji Pallonji Joyville Gurugram4.0 ★    39
# Signature Global Park4.0 ★                   36
# Shree Vardhman Victoria3.8 ★                 35
#                                              ..
# shree kirpalu gi sector 52                    1
# Meditech Apartment                            1
# Mariners Home                                 1
# IMT View Society                              1
# Spire Woods Now Ananda by Alpha corp          1
# Name: count, Length: 639, dtype: int64

# %%
import re

class DataCleaning:
    
    def __init__(self,df) -> None:
        self.df = df
    
    def split_bhk_area(self,prop_name):
        split_function = lambda x: pd.Series([x.split(' ')[0], ' '.join(x.split(' ')[1:])])
        
        df[['BHK','society1']] = df[prop_name].apply(split_function)
        df.drop(columns=[prop_name],inplace=True)
        
        return df
    
    def conv_price_unit_to_cr(self,prop_name):
        
        checks = ['Lacs','lac','LAKHS','lakh','Lakhs','lakhs','lacs','LACS','Lac']
        
        
        def convert_price(price):
            try:
                parts = str(price).split(' ')
                if len(parts)==2 and parts[1] in checks:
                    return float(parts[0])/100
                elif len(parts)==2 :
                    return parts[0]
                return price
            except (ValueError, AttributeError):
                return price
        
        self.df[prop_name] = self.df[prop_name].apply(convert_price)
        #renaming the column name
        self.df.rename(columns={prop_name:'price_in_cr'},inplace=True)
        # checked value_counts and got to know that this string was problem in the logic
        self.df = self.df[self.df['price_in_cr'] != 'Price on Request']
        return self.df
    
    def area_clean(self, area_feature):
        cleaned_values = []
        for val in df[area_feature]:
            try:
                # Ensuring the value is a string 
                val_str = str(val)
                # using the regular expression to remove unwanted characters
                cleaned_val = re.sub(r'[₹\s,/sq.ft]', '', val_str)
                # convert the cleaned value to integer
                cleaned_int = int(cleaned_val)
                cleaned_values.append(cleaned_int)
            except ValueError:
                #Handle the case where conversion to int fails
                cleaned_values.append(None)
            
        df['price_per_sqft'] = cleaned_values
        
        return df

# %%
DC = DataCleaning(df)
df = DC.split_bhk_area("property_name")

# %%
df.head()
# Out:
#                   society       price   price_per_sqft  \
# 0  maa bhagwati residency      45 Lac   ₹ 5,000/sq.ft.
# 1            Apna Enclave      50 Lac   ₹ 7,692/sq.ft.
# 2  Tulsiani Easy in Homes      40 Lac   ₹ 6,722/sq.ft.
# 3     Smart World Orchard  1.47 Crore  ₹ 12,250/sq.ft.
# 4        Parkwood Westend      70 Lac   ₹ 5,204/sq.ft.
#
#                              areaWithType     bedRoom     bathroom  \
# 0          Carpet area: 900 (83.61 sq.m.)  2 Bedrooms  2 Bathrooms
# 1          Carpet area: 650 (60.39 sq.m.)  2 Bedrooms  2 Bathrooms
# 2          Carpet area: 595 (55.28 sq.m.)  2 Bedrooms  2 Bathrooms
# 3        Carpet area: 1200 (111.48 sq.m.)  2 Bedrooms  2 Bathrooms
# 4  Super Built up area 1345(124.95 sq.m.)  2 Bedrooms  2 Bathrooms
#
#        balcony additionalRoom                              address  \
# 0    1 Balcony            NaN     Krishna Colony, Gurgaon, Haryana
# 1    1 Balcony            NaN   46b, Ashok Vihar, Gurgaon, Haryana
# 2  3 Balconies            NaN              Sohna, Gurgaon, Haryana
# 3  2 Balconies     Study Room  Sector 61 Gurgaon, Gurgaon, Haryana
# 4  3 Balconies     Study Room  Sector 92 Gurgaon, Gurgaon, Haryana
#
#               floorNum facing       agePossession  \
# 0    4th   of 4 Floors   West     1 to 5 Year Old
# 1    1st   of 3 Floors   West        10+ Year Old
# 2  12nd   of 14 Floors    NaN     0 to 1 Year Old
# 3    2nd   of 4 Floors    NaN            Dec 2023
# 4    5th   of 8 Floors    NaN  Under Construction
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2  ['Huda City Metro', 'Golf Course extn road', '...
# 3  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating BHK  \
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...   2
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...   2
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...   2
# 3                                                NaN   2
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...   2
#
#                         society1
# 0     BHK Flat in Krishna Colony
# 1        BHK Flat in Ashok Vihar
# 2              BHK Flat in Sohna
# 3  BHK Flat in Sector 61 Gurgaon
# 4  BHK Flat in Sector 92 Gurgaon

# %%
df = DC.conv_price_unit_to_cr('price')

# %%
df.sample(2)
# Out:
#                       society price_in_cr   price_per_sqft  \
# 41           Ashiana Mulberry        0.74   ₹ 6,200/sq.ft.
# 1893  La Vida by Tata Housing        2.35  ₹ 10,599/sq.ft.
#
#                                            areaWithType     bedRoom  \
# 41                     Carpet area: 1210 (112.41 sq.m.)  2 Bedrooms
# 1893  Super Built up area 2217(205.97 sq.m.)Built Up...  3 Bedrooms
#
#          bathroom       balcony additionalRoom  \
# 41    2 Bathrooms  3+ Balconies            NaN
# 1893  3 Bathrooms   3 Balconies   Servant Room
#
#                                     address             floorNum      facing  \
# 41                  Sohna, Gurgaon, Haryana  12nd   of 17 Floors  North-West
# 1893  Sector 113 Gurgaon , Gurgaon, Haryana  11st   of 25 Floors  North-East
#
#         agePossession                                    nearbyLocations  \
# 41    0 to 1 Year Old  ['Discount Department Store', 'Badshahpur Sohn...
# 1893  0 to 1 Year Old  ['Dwarka Sector 21', 'Pacific D21 Mall', 'Bajg...
#
#                                             description  \
# 41    Available with fully furnished kitchen and mas...
# 1893  This 3 bhk flat is located in la vida by tata ...
#
#                                          furnishDetails  \
# 41    ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 1893  ['1 Geyser', 'No AC', 'No Bed', 'No Chimney', ...
#
#                                                features  \
# 41    ['Security / Fire Alarm', 'Intercom Facility',...
# 1893  ['Centrally Air Conditioned', 'Water purifier'...
#
#                                                  rating BHK  \
# 41    ['Environment4 out of 5', 'Safety4 out of 5', ...   2
# 1893                                                NaN   3
#
#                             society1
# 41                 BHK Flat in Sohna
# 1893  BHK Flat in Sector 113 Gurgaon

# %%
df['price_per_sqft'].value_counts()
# Out:
# price_per_sqft
# ₹ 10,000/sq.ft.    19
# ₹ 12,500/sq.ft.    16
# ₹ 8,000/sq.ft.     16
# ₹ 6,666/sq.ft.     13
# ₹ 5,000/sq.ft.     13
#                    ..
# ₹ 12,401/sq.ft.     1
# ₹ 6,224/sq.ft.      1
# ₹ 8,179/sq.ft.      1
# ₹ 12,802/sq.ft.     1
# ₹ 35,222/sq.ft.     1
# Name: count, Length: 2131, dtype: int64

# %%
df = DC.area_clean("price_per_sqft")

# %%
df.sample(2)
# Out:
#                                society price_in_cr  price_per_sqft  \
# 881   Bestech Park View Residency3.9 ★       0.981          6932.0
# 2860                      Uphaar Homes        0.45          4736.0
#
#                                 areaWithType     bedRoom     bathroom  \
# 881   Super Built up area 1415(131.46 sq.m.)  2 Bedrooms  2 Bathrooms
# 2860          Carpet area: 950 (88.26 sq.m.)  3 Bedrooms  2 Bathrooms
#
#           balcony additionalRoom                               address  \
# 881   3 Balconies            NaN         Palam Vihar, Gurgaon, Haryana
# 2860    1 Balcony            NaN  Sector 105 Gurgaon, Gurgaon, Haryana
#
#                  floorNum facing     agePossession  \
# 881   11st   of 14 Floors   East  5 to 10 Year Old
# 2860    1st   of 4 Floors    NaN   1 to 5 Year Old
#
#                                         nearbyLocations  \
# 881   ['Dwarka Sector 21 Metro Station', 'HUDA Marke...
# 2860  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 881   Bestech park view residency is one of gurgaon'...
# 2860  Well guarded, peace of mind, 24x7 water, nearb...
#
#                                          furnishDetails  \
# 881   ['2 Wardrobe', '4 Fan', '1 Geyser', '5 Light',...
# 2860  ['5 Fan', '1 Exhaust Fan', '1 Geyser', '14 Lig...
#
#                                                features  \
# 881   ['Security / Fire Alarm', 'Power Back-up', 'Li...
# 2860  ['Power Back-up', 'Feng Shui / Vaastu Complian...
#
#                                                  rating BHK  \
# 881   ['Green Area5 out of 5', 'Construction4 out of...   2
# 2860  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...   3
#
#                             society1
# 881          BHK Flat in Palam Vihar
# 2860  BHK Flat in Sector 105 Gurgaon

# %%
df.isnull().sum()
# 20 flats are their about which price is not provided 
df = df[~df['price_in_cr'].isnull()]

# %%
df.isnull().sum()
# Out:
# society               1
# price_in_cr           0
# price_per_sqft        1
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom     1304
# address               6
# floorNum              2
# facing              874
# agePossession         1
# nearbyLocations      91
# description           0
# furnishDetails      796
# features            407
# rating              328
# BHK                   0
# society1              0
# dtype: int64

# %%
df =df[~df['price_per_sqft'].isnull()]

# %%
df['bedRoom'].value_counts()
# easy to cleamn
# Out:
# bedRoom
# 3 Bedrooms    1437
# 2 Bedrooms     943
# 4 Bedrooms     478
# 1 Bedroom      104
# 5 Bedrooms      31
# 6 Bedrooms       3
# Name: count, dtype: int64

# %%
df['bedRoom'] = df['bedRoom'].apply(lambda x: int(x.split(' ')[0]) if x else 0)
df['bathroom'] = df['bathroom'].apply(lambda x: int(x.split(' ')[0]) if x else 0)

# %%
#df['balcony'] = df['balcony'].apply(lambda x: int(x.split(' ')[0]) if x else 0)
df['balcony'].value_counts()
# Out:
# balcony
# 3 Balconies     973
# 3+ Balconies    862
# 2 Balconies     749
# 1 Balcony       315
# No Balcony       97
# Name: count, dtype: int64

# %%
def bal(count):
    if count.split(' ')[0]=="3+":
        return 3
    elif count.split(' ')[0]=="No":
        return 0
    else:
        return int(count.split(' ')[0])

# %%
df['balcony']= df['balcony'].apply(bal)

# %%
df.head()
# Out:
#                   society price_in_cr  price_per_sqft  \
# 0  maa bhagwati residency        0.45          5000.0
# 1            Apna Enclave         0.5          7692.0
# 2  Tulsiani Easy in Homes         0.4          6722.0
# 3     Smart World Orchard        1.47         12250.0
# 4        Parkwood Westend         0.7          5204.0
#
#                              areaWithType  bedRoom  bathroom  balcony  \
# 0          Carpet area: 900 (83.61 sq.m.)        2         2        1
# 1          Carpet area: 650 (60.39 sq.m.)        2         2        1
# 2          Carpet area: 595 (55.28 sq.m.)        2         2        3
# 3        Carpet area: 1200 (111.48 sq.m.)        2         2        2
# 4  Super Built up area 1345(124.95 sq.m.)        2         2        3
#
#   additionalRoom                              address             floorNum  \
# 0            NaN     Krishna Colony, Gurgaon, Haryana    4th   of 4 Floors
# 1            NaN   46b, Ashok Vihar, Gurgaon, Haryana    1st   of 3 Floors
# 2            NaN              Sohna, Gurgaon, Haryana  12nd   of 14 Floors
# 3     Study Room  Sector 61 Gurgaon, Gurgaon, Haryana    2nd   of 4 Floors
# 4     Study Room  Sector 92 Gurgaon, Gurgaon, Haryana    5th   of 8 Floors
#
#   facing       agePossession  \
# 0   West     1 to 5 Year Old
# 1   West        10+ Year Old
# 2    NaN     0 to 1 Year Old
# 3    NaN            Dec 2023
# 4    NaN  Under Construction
#
#                                      nearbyLocations  \
# 0  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2  ['Huda City Metro', 'Golf Course extn road', '...
# 3  ['Sector 55-56 Metro station', 'Bestech Centra...
# 4  ['Yadav Clinic', 'Bangali Clinic', 'Dr. J. S. ...
#
#                                          description  \
# 0  So with lift.Maa bhagwati residency is one of ...
# 1  Property situated on main road, railway statio...
# 2  This property is 15 km away from badshapur, gu...
# 3  Near to metro station of sector 56 and opposit...
# 4  We are the proud owners of this 2 bhk alongwit...
#
#                                       furnishDetails  \
# 0  ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1  ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                NaN
# 3                                                NaN
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1  ['Security / Fire Alarm', 'Maintenance Staff',...
# 2  ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 3  ['Security / Fire Alarm', 'Private Garden / Te...
# 4                                                NaN
#
#                                               rating BHK  \
# 0  ['Environment4 out of 5', 'Safety4 out of 5', ...   2
# 1  ['Environment4 out of 5', 'Safety4 out of 5', ...   2
# 2  ['Environment4 out of 5', 'Safety4 out of 5', ...   2
# 3                                                NaN   2
# 4  ['Environment5 out of 5', 'Safety3 out of 5', ...   2
#
#                         society1
# 0     BHK Flat in Krishna Colony
# 1        BHK Flat in Ashok Vihar
# 2              BHK Flat in Sohna
# 3  BHK Flat in Sector 61 Gurgaon
# 4  BHK Flat in Sector 92 Gurgaon

# %%
df.insert(loc=3,column='sector',value=df['society1'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
import re
df['society'] = df['society'].apply(lambda name: re.sub(r'\d+(\.\d+)?\s?★', '', str(name)).strip()).str.lower()

# %%
df.drop(columns=['society1','address'],inplace=True)

# %%
df[df['additionalRoom'].isnull()]
# Out:
#                              society price_in_cr  price_per_sqft  \
# 0             maa bhagwati residency        0.45          5000.0
# 1                       apna enclave         0.5          7692.0
# 2             tulsiani easy in homes         0.4          6722.0
# 5     signature global infinity mall        0.41          6269.0
# 6                         the cocoon           2         13333.0
# ...                              ...         ...             ...
# 3017                 pareena mi casa         1.7          8500.0
# 3018             palam vihar society         0.4          8602.0
# 3019                   m3m woodshire         1.4          5929.0
# 3020              krishna appartment        0.35          3500.0
# 3022                dlf regency park        1.35         11992.0
#
#                  sector                                       areaWithType  \
# 0        Krishna Colony                     Carpet area: 900 (83.61 sq.m.)
# 1           Ashok Vihar                     Carpet area: 650 (60.39 sq.m.)
# 2                 Sohna                     Carpet area: 595 (55.28 sq.m.)
# 5             Sector 36                   Built Up area: 654 (60.76 sq.m.)
# 6     Dwarka Expressway             Super Built up area 1500(139.35 sq.m.)
# ...                 ...                                                ...
# 3017          Sector 68             Super Built up area 1999(185.71 sq.m.)
# 3018        Palam Vihar  Super Built up area 465(43.2 sq.m.)Built Up ar...
# 3019         Sector 107             Super Built up area 2361(219.34 sq.m.)
# 3020      Dharam Colony               Super Built up area 1000(92.9 sq.m.)
# 3022        DLF Phase 4                 Built Up area: 1109 (103.03 sq.m.)
#
#       bedRoom  bathroom  balcony additionalRoom             floorNum facing  \
# 0           2         2        1            NaN    4th   of 4 Floors   West
# 1           2         2        1            NaN    1st   of 3 Floors   West
# 2           2         2        3            NaN  12nd   of 14 Floors    NaN
# 5           2         2        3            NaN    3rd   of 3 Floors    NaN
# 6           3         3        3            NaN   5th   of 25 Floors    NaN
# ...       ...       ...      ...            ...                  ...    ...
# 3017        4         4        3            NaN  23rd   of 36 Floors    NaN
# 3018        1         1        1            NaN   5th   of 16 Floors  North
# 3019        3         4        0            NaN   1st   of 14 Floors   East
# 3020        3         3        1            NaN    2nd   of 5 Floors    NaN
# 3022        2         2        2            NaN   1st   of 26 Floors    NaN
#
#          agePossession                                    nearbyLocations  \
# 0      1 to 5 Year Old  ['Chintapurni Mandir', 'State bank ATM', 'Pear...
# 1         10+ Year Old  ['Chintapurni Mandir', 'Sheetla Mata Mandir', ...
# 2      0 to 1 Year Old  ['Huda City Metro', 'Golf Course extn road', '...
# 5            undefined                                                NaN
# 6      0 to 1 Year Old  ['Shri Multispeciality Hospital', 'Esic Hospit...
# ...                ...                                                ...
# 3017   0 to 1 Year Old  ['Sector 55-56 Metro Station', 'Airia Mall', '...
# 3018  5 to 10 Year Old  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3019   0 to 1 Year Old                                                NaN
# 3020      10+ Year Old  ['Palam triangle', 'Palam Vihar Vyapar kendra'...
# 3022  5 to 10 Year Old  ['Sector 42-43 metro station', 'Dlf phase 1 me...
#
#                                             description  \
# 0     So with lift.Maa bhagwati residency is one of ...
# 1     Property situated on main road, railway statio...
# 2     This property is 15 km away from badshapur, gu...
# 5     Best in class property available at sector 36 ...
# 6     Residential apartment for sell.The property co...
# ...                                                 ...
# 3017  The property is on the 23rd floor with an road...
# 3018  One of the best locations with malls, schools,...
# 3019  Looking for a good 3 bhk apartment in sector 1...
# 3020  Residential apartment for sell.Located on 2nd ...
# 3022  Interested to sell residential apartment . It ...
#
#                                          furnishDetails  \
# 0     ['3 Fan', '4 Light', '1 Wardrobe', 'No AC', 'N...
# 1     ['3 Wardrobe', '4 Fan', '1 Exhaust Fan', '1 Ge...
# 2                                                   NaN
# 5                                                   NaN
# 6                                                    []
# ...                                                 ...
# 3017  ['1 Modular Kitchen', 'No AC', 'No Bed', 'No C...
# 3018  ['1 Water Purifier', '1 Fan', '1 Fridge', '1 E...
# 3019  ['1 Light', 'No AC', 'No Bed', 'No Chimney', '...
# 3020  ['3 Wardrobe', '3 Fan', '3 Light', 'No AC', 'N...
# 3022                                                 []
#
#                                                features  \
# 0     ['Feng Shui / Vaastu Compliant', 'Security / F...
# 1     ['Security / Fire Alarm', 'Maintenance Staff',...
# 2     ['Power Back-up', 'Feng Shui / Vaastu Complian...
# 5                                                   NaN
# 6                                                   NaN
# ...                                                 ...
# 3017  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3018  ['Centrally Air Conditioned', 'Lift(s)', 'Park...
# 3019  ['Power Back-up', 'Intercom Facility', 'Lift(s...
# 3020                                                NaN
# 3022                                                NaN
#
#                                                  rating BHK
# 0     ['Environment4 out of 5', 'Safety4 out of 5', ...   2
# 1     ['Environment4 out of 5', 'Safety4 out of 5', ...   2
# 2     ['Environment4 out of 5', 'Safety4 out of 5', ...   2
# 5                                                   NaN   2
# 6                                                   NaN   3
# ...                                                 ...  ..
# 3017  ['Safety5 out of 5', 'Lifestyle4 out of 5', 'E...   4
# 3018  ['Safety4 out of 5', 'Lifestyle5 out of 5', 'E...   1
# 3019  ['Safety1 out of 5', 'Lifestyle2 out of 5', 'E...   3
# 3020  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...   3
# 3022  ['Management5 out of 5', 'Green Area5 out of 5...   2
#
# [1304 rows x 18 columns]

# %%
df['additionalRoom'].value_counts()
# Out:
# additionalRoom
# Servant Room                                     629
# Study Room                                       232
# Others                                           179
# Pooja Room                                       132
# Study Room,Servant Room                           81
# Store Room                                        76
# Pooja Room,Servant Room                           60
# Servant Room,Others                               52
# Servant Room,Pooja Room                           30
# Study Room,Others                                 27
# Pooja Room,Study Room,Servant Room,Others         25
# Pooja Room,Study Room,Servant Room                24
# Servant Room,Store Room                           19
# Pooja Room,Study Room                             13
# Pooja Room,Study Room,Servant Room,Store Room     12
# Study Room,Pooja Room                              8
# Servant Room,Study Room                            8
# Study Room,Servant Room,Store Room                 7
# Pooja Room,Store Room                              6
# Pooja Room,Others                                  6
# Others,Servant Room                                6
# Servant Room,Study Room,Pooja Room,Store Room      6
# Pooja Room,Servant Room,Others                     6
# Study Room,Servant Room,Others                     5
# Pooja Room,Store Room,Study Room,Servant Room      4
# Pooja Room,Study Room,Store Room                   4
# Servant Room,Pooja Room,Study Room,Store Room      3
# Study Room,Pooja Room,Store Room                   3
# Store Room,Servant Room                            3
# Servant Room,Study Room,Store Room                 2
# Pooja Room,Study Room,Others                       2
# Study Room,Pooja Room,Servant Room                 2
# Servant Room,Others,Store Room,Pooja Room          2
# Servant Room,Others,Pooja Room                     2
# Study Room,Servant Room,Pooja Room,Store Room      2
# Others,Study Room                                  1
# Servant Room,Study Room,Others                     1
# Servant Room,Pooja Room,Study Room                 1
# Servant Room,Study Room,Pooja Room                 1
# Store Room,Pooja Room,Servant Room                 1
# Servant Room,Pooja Room,Store Room,Study Room      1
# Study Room,Store Room                              1
# Store Room,Study Room                              1
# Servant Room,Pooja Room,Store Room                 1
# Study Room,Servant Room,Store Room,Pooja Room      1
# Study Room,Servant Room,Pooja Room                 1
# Pooja Room,Servant Room,Study Room,Store Room      1
# Pooja Room,Study Room,Store Room,Servant Room      1
# Store Room,Pooja Room                              1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# society               0
# price_in_cr           0
# price_per_sqft        0
# sector                0
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom     1304
# floorNum              2
# facing              874
# agePossession         1
# nearbyLocations      91
# description           0
# furnishDetails      796
# features            407
# rating              328
# BHK                   0
# dtype: int64

# %%
df['areaWithType'].value_counts()

# carpet area is the area that is actually used for living  (internal wall thickness counted and external not counted)
# builtup area = carpet area + external walls + service shafts + balconies
# super built up area = everything included
# Out:
# areaWithType
# Super Built up area 1350(125.42 sq.m.)                                                                                    17
# Super Built up area 1578(146.6 sq.m.)                                                                                     17
# Super Built up area 1950(181.16 sq.m.)Carpet area: 1161 sq.ft. (107.86 sq.m.)                                             17
# Super Built up area 1650(153.29 sq.m.)Carpet area: 1022.58 sq.ft. (95 sq.m.)                                              15
# Super Built up area 2010(186.74 sq.m.)                                                                                    14
#                                                                                                                           ..
# Super Built up area 1976(183.58 sq.m.)Built Up area: 1600 sq.ft. (148.64 sq.m.)Carpet area: 1400 sq.ft. (130.06 sq.m.)     1
# Carpet area: 4328 (402.08 sq.m.)                                                                                           1
# Super Built up area 1950(181.16 sq.m.)Carpet area: 1267 sq.ft. (117.71 sq.m.)                                              1
# Super Built up area 1822(169.27 sq.m.)Carpet area: 1400 sq.ft. (130.06 sq.m.)                                              1
# Super Built up area 3123(290.14 sq.m.)                                                                                     1
# Name: count, Length: 1924, dtype: int64
